# %% [markdown]
# <a href="https://colab.research.google.com/github/BhojRajBist/BhojRajBist/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
# Create two points
point1 = Point(85.3240, 27.7172)  # Kathmandu
point2 = Point(84.0918, 28.3949)  # Pokhara

# Create a GeoDataFrame
gdf = gpd.GeoDataFrame({'City': ['Kathmandu', 'Pokhara']}, geometry=[point1, point2])

# Buffer operation (creates a circle around the points)
gdf['Buffer'] = gdf.geometry.buffer(1.0)

print(gdf)

# Plot the buffered geometries
gdf.plot(figsize=(10, 6), edgecolor='black', alpha=0.5)
plt.show()
# Out:
#         City                 geometry  \
# 0  Kathmandu   POINT (85.324 27.7172)
# 1    Pokhara  POINT (84.0918 28.3949)
#
#                                               Buffer
# 0  POLYGON ((86.324 27.7172, 86.31918 27.61918, 8...
# 1  POLYGON ((85.0918 28.3949, 85.08698 28.29688, ...
