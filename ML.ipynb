# %% [markdown]
# <a href="https://colab.research.google.com/github/BhojRajBist/BhojRajBist/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

import numpy as np
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt


np.random.seed(0)
X = np.random.rand(50,1)*10
y= 2.5 *X + np.random.randn(50,1)*2

model = LinearRegression()
model.fit(X,y)





# Make predictions
y_pred = model.predict(X)

# Visualize the data and the fitted line
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, y_pred, color='red', label='Fitted Line')
plt.xlabel('Feature (X)')
plt.ylabel('Target (y)')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import numpy as np

# Generate synthetic classification data
X, y = make_classification(n_features=2, n_redundant=0, n_clusters_per_class=1, n_samples=200, random_state=42)

# Train a decision tree classifier
model = DecisionTreeClassifier(max_depth=3)
model.fit(X, y)

# Create a mesh to plot decision boundaries
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary and data points
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.RdYlBu)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor='k', cmap=plt.cm.RdYlBu)
plt.title('Decision Tree Classification Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Apply PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
X_r = pca.fit_transform(X)

# Plot the reduced data
colors = ['navy', 'turquoise', 'darkorange']
for i, color, target_name in zip([0, 1, 2], colors, target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=0.8, label=target_name)

plt.title('PCA of Iris Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
